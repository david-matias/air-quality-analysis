# %% [markdown]
# """
# # 📊 Análise Exploratória - Qualidade do Ar
# ## Projeto: Análise de Qualidade do Ar em Cidades Globais
#
# **Autor:** [David Matias]
# **Data:** 29/12/2025
# **Versão:** 1.0
#
# Este notebook realiza análise exploratória dos dados de qualidade do ar.
# """

# %%
# Análise Exploratória - Qualidade do Ar

import sys
sys.path.append('../src')

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px

# Configurações
plt.style.use('seaborn-v0_8-darkgrid')
sns.set_palette('husl')
pd.set_option('display.max_columns', None)

# Carregar dados
from data_collection import DataCollector
from data_cleaning import clean_air_quality_data

print("📥 Carregando dados...")
collector = DataCollector()
raw_data = collector.get_data(use_sample=True)
cleaned_data = clean_air_quality_data(raw_data, save_path=None)

print(f"✅ Dados carregados: {len(cleaned_data):,} registros")
print(f"📅 Período: {cleaned_data['date'].min()} a {cleaned_data['date'].max()}")
print(f"🏙️ Cidades: {cleaned_data['city'].nunique()}")
print(f"🌫️ Poluentes: {', '.join(cleaned_data['parameter'].unique())}")

# Visualização básica
fig = px.box(cleaned_data, x='city', y='value', color='parameter',
             title='Distribuição de Poluentes por Cidade')
fig.show()
# Out:
# 📥 Carregando dados...
# ...
# 🌍 COLETA DE DADOS - QUALIDADE DO AR
# ...
# 📥 Método 2: Criando dataset de exemplo para desenvolvimento
# ✅ Dataset de exemplo criado: 5,400 registros
# 💾 Salvo em: ./data\raw\sample_data.csv
# 🧹 Iniciando limpeza de dados...
#   🔄 Convertendo tipos de dados...
#   🔍 Colunas disponíveis: ['date', 'city', 'country', 'parameter', 'value', 'unit', 'latitude', 'longitude']
#   🗑️  Removendo duplicatas usando: ['date', 'city', 'parameter', 'value', 'latitude', 'longitude']
#   🔍 Tratando valores ausentes...
#     Valores ausentes: 0 → 0
#   ⏰ Criando features temporais...
#   ✅ Validando dados...
#     📈 Dimensões: (5400, 13)
#     📅 Período: 2020-01-01 00:00:00 a 2020-06-28 00:00:00
# ✅ Limpeza concluída! Registros: 5,400
# ✅ Dados carregados: 5,400 registros
# 📅 Período: 2020-01-01 00:00:00 a 2020-06-28 00:00:00
# 🏙️ Cidades: 10
# 🌫️ Poluentes: PM2.5, NO2, O3
