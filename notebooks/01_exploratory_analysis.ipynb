# %% [markdown]
# """
# # 📊 Análise Exploratória - Qualidade do Ar
# ## Projeto: Análise de Qualidade do Ar em Cidades Globais
#
# **Autor:** [David Matias]
# **Data:** 29/12/2025
# **Versão:** 1.0
#
# Este notebook realiza análise exploratória dos dados de qualidade do ar.
# """

# %%
# 1. CONFIGURAÇÃO INICIAL
import sys
import os
sys.path.append('../../src')

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as go
from plotly.subplots import make_subplots

# Configurações de estilo
plt.style.use('seaborn-v0_8-darkgrid')
sns.set_palette("husl")
pd.set_option('display.max_columns', None)
pd.set_option('display.float_format', '{:.2f}'.format)

print("✅ Pacotes carregados com sucesso!")
# Out:
# ✅ Pacotes carregados com sucesso!

# %%
# 2. CARREGAMENTO DE DADOS
from src.data_collection import DataCollector

print("📥 Carregando dados...")
collector = DataCollector()
df = collector.get_data(use_sample=True)

print(f"\n📊 Dimensões do dataset: {df.shape}")
print(f"📅 Período: {df['date'].min()} a {df['date'].max()}")
print(f"🏙️ Cidades: {len(df['city'].unique())}")
print(f"🌫️ Poluentes: {df['parameter'].unique().tolist()}")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[10], line 2
#       1 # 2. CARREGAMENTO DE DADOS
# ----> 2 from src.data_collection import DataCollector
#       4 print("📥 Carregando dados...")
#       5 collector = DataCollector()
#
# ModuleNotFoundError: No module named 'src'

# %%
# 3. PRIMEIRA VISUALIZAÇÃO
print("\n🎯 Primeiras visualizações...")

# Distribuição por cidade
fig = px.box(df, x='city', y='value', color='parameter',
             title='Distribuição de Poluentes por Cidade',
             labels={'value': 'Concentração (µg/m³)', 'city': 'Cidade'})
fig.show()
